# %%
import numpy as np
import pandas as pd
import os
import glob
import shutil
from tensorflow import keras
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.layers import Masking
import keras_tuner as kt
from pathlib import Path
import joblib # for saving and loading variables
import io
import contextlib
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, balanced_accuracy_score
import csv

# %%
for it in range(42,50):
    a = it
    joblib.dump(a,'it.sav')
    
    print('current iteration',a)
    
    # %run LSTM_stratified_singleElectrode.ipynb
# Out:
# current iteration 42
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_42
# C:\Users\ilkele4s\Data\Electrodes\electrode_42.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.6058201058201059
# current iteration 43
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_43
# C:\Users\ilkele4s\Data\Electrodes\electrode_43.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.6851851851851851
# current iteration 44
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_44
# C:\Users\ilkele4s\Data\Electrodes\electrode_44.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 4ms/step
# Weighted accuracy is: 0.6343915343915345
# current iteration 45
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_45
# C:\Users\ilkele4s\Data\Electrodes\electrode_45.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 2ms/step
# Weighted accuracy is: 0.6560846560846562
# current iteration 46
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_46
# C:\Users\ilkele4s\Data\Electrodes\electrode_46.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 2ms/step
# Weighted accuracy is: 0.617989417989418
# current iteration 47
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_47
# C:\Users\ilkele4s\Data\Electrodes\electrode_47.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.5925925925925926
# current iteration 48
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_48
# C:\Users\ilkele4s\Data\Electrodes\electrode_48.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.5391534391534392
# current iteration 49
# C:\Users\ilkele4s\ML_Results\LSTM_stratified_singleElectrode_results\electrode_49
# C:\Users\ilkele4s\Data\Electrodes\electrode_49.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.607936507936508
