# %%
import numpy as np
import pandas as pd
import os
import glob
import shutil
from tensorflow import keras
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from keras.layers import Dense, LSTM
from keras.models import Sequential
from keras.layers import Masking
import keras_tuner as kt
from pathlib import Path
import joblib # for saving and loading variables
import io
import contextlib
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import classification_report, balanced_accuracy_score

# %%
for it in range(43,50):
    a = it2
    joblib.dump(a,'it2.sav')
    
    print('current electrode',a)
    
    # %run LSTM_noFunction_singleElectrode.ipynb
# Out:
# current electrode 43
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_43
# C:\Users\ilkele4s\Data\Electrodes\electrode_43.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 3ms/step
# Weighted accuracy is: 0.6630335097001764
# current electrode 44
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_44
# C:\Users\ilkele4s\Data\Electrodes\electrode_44.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 3ms/step
# Weighted accuracy is: 0.5950088183421518
# current electrode 45
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_45
# C:\Users\ilkele4s\Data\Electrodes\electrode_45.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.6471180054513389
# current electrode 46
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_46
# C:\Users\ilkele4s\Data\Electrodes\electrode_46.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.6582563732563733
# current electrode 47
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_47
# C:\Users\ilkele4s\Data\Electrodes\electrode_47.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 0s 2ms/step
# Weighted accuracy is: 0.5472711239377906
# current electrode 48
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_48
# C:\Users\ilkele4s\Data\Electrodes\electrode_48.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 2ms/step
# Weighted accuracy is: 0.5089866923200257
# current electrode 49
# C:\Users\ilkele4s\ML_Results\LSTM_noFunction_singleElectrode_results\electrode_49
# C:\Users\ilkele4s\Data\Electrodes\electrode_49.csv
# INFO:tensorflow:Oracle triggered exit
# 9/9 [==============================] - 1s 3ms/step
# Weighted accuracy is: 0.6192857142857143

# %%
with open(csv_filename, 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    for row in csv_reader:
        print(row)
